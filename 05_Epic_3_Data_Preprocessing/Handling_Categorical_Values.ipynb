# %% [markdown]
# # Handling Categorical Values
#
# The purpose of handling categorical values and scaling features is to encode text features and normalize numeric ranges. It is used to prepare the dataset for model training, as models require numeric inputs on similar scales. In this project, categorical variables are encoded using LabelEncoder, and numerical features are scaled using StandardScaler. The encoders and scalers are saved as encoder.pkl and scaler.pkl, and the preprocessed data is exported as processed_dataset.csv. The project-specific usage avoids data leakage by dropping credit history aggregates from the training features. The result is a normalized dataset with 18 features and 5,000 rows, ready for model training.

# %%
import os
import pandas as pd
import joblib
from sklearn.preprocessing import LabelEncoder, StandardScaler
print('Preprocessing tasks initialized.')
