# %% [markdown]
# # Importing Core Libraries
#
# ### Objective:
# Import and set up the analytics, numerical, and visualization dependencies.
#
# ### Introduction:
# This notebook handles the initial setup by importing all required external Python dependencies. It loads Pandas for structured data manipulation, NumPy for mathematical array operations, and Matplotlib and Seaborn to construct visualizations. It also configures warnings to be ignored to keep execution outputs clean and sets a consistent visual theme. Importing libraries at the beginning of a workflow establishes a centralized dependency setup, ensuring that all down-stream notebooks have access to consistent software packages and execution environments. In this project, the core analytics libraries are imported at startup, allowing for seamless exploratory data analysis, data cleaning, and features normalization across the subsequent stages of the pipeline.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_theme(style='whitegrid')
print('Libraries imported successfully.')

# %% [markdown]
# ### Observations & Conclusion:
# All core python analytics libraries (Pandas, NumPy, Matplotlib, Seaborn, OS) loaded successfully and warning outputs were suppressed. The workspace is set up correctly for data analysis.
