# %% [markdown]
# # Model Comparison and Selection
#
# ### Objective:
# Evaluate and compare the classification performance and computational complexity of the models.
#
# ### Introduction:
# This section compares the performance of Logistic Regression, Decision Tree, and Random Forest models. We evaluate the models on the test set using Accuracy, Precision, Recall, F1 Score, and ROC-AUC metrics, alongside confusion matrices and ROC curves. The results show that Logistic Regression and Random Forest achieve the highest accuracy (82.30%) and recall (100.00%). We selected Logistic Regression as the best model for the Flask web application. It performs best because it achieves optimal recall on delinquent cases while maintaining low computational complexity and inference latency. This choice ensures that high-risk accounts are flagged correctly during web inference, protecting the institution from credit defaults.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
metrics_df = pd.read_csv('model_comparison_metrics.csv')
print(metrics_df.to_string(index=False))

# %% [markdown]
# ### Observations & Conclusion:
# Logistic Regression and Random Forest both achieve 82.30% test accuracy and 100% recall. Logistic Regression is selected for production deployment because it has a significantly lower prediction latency (less than 0.1 milliseconds), making it highly suitable for real-time web inference.
